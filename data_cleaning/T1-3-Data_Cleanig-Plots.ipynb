# %% [markdown]
# # Plots & Data Visualization

# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../datasets/customer-churn-model/Customer Churn Model.txt")

# %%
df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
# %matplotlib inline

# %%
#savefig("path_save_image.jpeg")

# %% [markdown]
# ## Scatter Plot

# %%
df.plot(kind="scatter", x="Day Mins", y= "Day Charge")  # linear correlation - linear regression
# Out:
# <AxesSubplot:xlabel='Day Mins', ylabel='Day Charge'>

# %%
df.plot(kind="scatter", x="Night Mins", y= "Night Charge")
# Out:
# <AxesSubplot:xlabel='Night Mins', ylabel='Night Charge'>

# %%
figure, axs = plt.subplots(2,2, sharey=True, sharex=True)
df.plot(kind="scatter", x="Day Mins", y="Day Charge", ax= axs[0][0]) # subplot
df.plot(kind="scatter", x="Night Mins", y="Night Charge", ax= axs[0][1])
df.plot(kind="scatter", x="Day Calls", y="Day Charge", ax= axs[1][0])
df.plot(kind="scatter", x="Night Calls", y="Night Charge", ax= axs[1][1])
# Out:
# <AxesSubplot:xlabel='Night Calls', ylabel='Night Charge'>

# %% [markdown]
# ## Frequency Histogram

# %%
plt.hist(df["Day Calls"], bins=20) # divisions  [0,30,60,90,120,150]
plt.xlabel("Number of calls per day")
plt.ylabel("Frequency of calls per day")
plt.title("Histogram of number of calls per day")
# Out:
# Text(0.5, 1.0, 'Histogram of number of calls per day')

# %%
k = int(np.ceil(1+np.log2(3333)))  # Sturges Rule
plt.hist(df["Day Calls"], bins= k)
plt.xlabel("Number of calls per day")
plt.ylabel("Frequency of calls per day")
plt.title("Histogram of number of calls per day")
# Out:
# Text(0.5, 1.0, 'Histogram of number of calls per day')

# %% [markdown]
# ## BoxPlot - Box-and-whisker plot

# %%
plt.boxplot(df["Day Calls"])
plt.ylabel("Number of calls per day")
plt.title("Boxplot Day Calls")
# Out:
# Text(0.5, 1.0, 'Boxplot Day Calls')

# %%
df["Day Calls"].describe()
# Out:
# count    3333.000000
# mean      100.435644
# std        20.069084
# min         0.000000
# 25%        87.000000
# 50%       101.000000
# 75%       114.000000
# max       165.000000
# Name: Day Calls, dtype: float64

# %%
# Interquartile Range

IQR= df["Day Calls"].quantile(0.75)-df["Day Calls"].quantile(0.25)
IQR
# Out:
# 27.0

# %%
df["Day Calls"].quantile(0.25) - 1.5*IQR  # Find Outlayers
# Out:
# 46.5

# %%
df["Day Calls"].quantile(0.75) + 1.5*IQR  # Find Outlayers
# Out:
# 154.5
